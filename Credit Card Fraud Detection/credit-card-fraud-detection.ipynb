# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# **Loading the Data**

# %%
data = pd.read_csv("/kaggle/input/creditcardfraud/creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data.Amount.describe().round(2)
# Out:
# count    284807.00
# mean         88.35
# std         250.12
# min           0.00
# 25%           5.60
# 50%          22.00
# 75%          77.16
# max       25691.16
# Name: Amount, dtype: float64

# %% [markdown]
# **Check for missing values**

# %%
print("Missing values:\n", data.isnull().sum())
# Out:
# Missing values:
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Distribution of Classes

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x='Class', data=data)
plt.title('Distribution of Classes')
plt.xlabel('Class')
plt.ylabel('Number of Transactions')
plt.show()

# %% [markdown]
# Transaction Amount by Class

# %%
plt.figure(figsize=(9, 5))
sns.boxplot(x='Class', y='Amount', data=data)
plt.title('Transaction Amount by Class')
plt.xlabel('Class')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
data.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# Fraudulent vs Genuine Transactions in the Dataset

# %%
class_distribution = data['Class'].value_counts()
fig = px.pie(names=['Genuine', 'Fraud'], values=class_distribution, 
             title='Fraudulent vs Genuine Transactions in the Dataset')
fig.update_traces(textinfo='percent+label', pull=[0.05, 0.05], 
                  marker=dict(colors=['#636EFA', '#EF553B'], line=dict(color='#FFFFFF', width=2)))
fig.update_layout(title_font=dict(size=20), title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="4900d2bf-d012-41c6-ad3a-4c24d26ecfe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4900d2bf-d012-41c6-ad3a-4c24d26ecfe2")) {                    Plotly.newPlot(                        "4900d2bf-d012-41c6-ad3a-4c24d26ecfe2",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Genuine","Fraud"],"legendgroup":"","name":"","showlegend":true,"values":[284315,492],"type":"pie","marker":{"line":{"color":"#FFFFFF","width":2},"colors":["#636EFA","#EF553B"]},"pull":[0.05,0.05],"textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcon
# ...

# %%
data.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'],
#       dtype='object')

# %% [markdown]
# Descriptive Statistics for Fraudulent Transactions Amount

# %%
fraudulent_amount_stats = data[data['Class'] == 1]['Amount'].describe().round(2)
print("Descriptive Statistics for Fraudulent Transactions Amount:")
print(fraudulent_amount_stats)
# Out:
# Descriptive Statistics for Fraudulent Transactions Amount:
# count     492.00
# mean      122.21
# std       256.68
# min         0.00
# 25%         1.00
# 50%         9.25
# 75%       105.89
# max      2125.87
# Name: Amount, dtype: float64

# %%
X = data.drop(columns=['Class'], axis=1)  
y = data['Class']

# %% [markdown]
# **Splitting the Data into Training and Test Sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# **Standardizing the Explanatory Variables**

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# **SVM Model **

# %%
model_svc = SVC()
model_svc.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# **Evaluation**

# %%
train_accuracy = model_svc.score(X_train, y_train)
test_accuracy = model_svc.score(X_test, y_test)
print("Accuracy on training set:", train_accuracy)
print("Accuracy on test set:", test_accuracy)
# Out:
# Accuracy on training set: 0.9996752178015756
# Accuracy on test set: 0.999385555282469

# %% [markdown]
# **Predictions**

# %%
y_predict = model_svc.predict(X_test)

# %% [markdown]
# **Classification Report and Confusion Matrix**

# %%
print(classification_report(y_test, y_predict))
confusion = confusion_matrix(y_test, y_predict)
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', 
            xticklabels=['Genuine', 'Fraud'], yticklabels=['Genuine', 'Fraud'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56875
#            1       0.95      0.63      0.76        87
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.82      0.88     56962
# weighted avg       1.00      1.00      1.00     56962
